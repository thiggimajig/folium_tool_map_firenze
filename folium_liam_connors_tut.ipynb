# %%
import pandas as pd
import folium

# %% [markdown]
# creating a dataframe from our dataset csv file

# %%
listings = "../thesis_app/Out_CSV/florence_listings_jan_27_cleaned_trimmed500_2022_02_15_21_51_51.csv"
prelim_listings_location = pd.read_csv(listings)

# %% [markdown]
# shorten dataframe even more so doensn't take so long

# %%
listings_location = prelim_listings_location.loc[:50, :]

# %% [markdown]
# checking the new dataframe

# %%
listings_location.head()
# Out:
#    listing_number     id                         listing_url  \
# 0               0  24469  https://www.airbnb.com/rooms/24469
# 1               1  24470  https://www.airbnb.com/rooms/24470
# 2               2  24471  https://www.airbnb.com/rooms/24471
# 3               3  24472  https://www.airbnb.com/rooms/24472
# 4               4  26738  https://www.airbnb.com/rooms/26738
#
#                                   name  host_id              host_name  \
# 0  Fortezza/City Centre Modern Apt 2+2    99178  Benedetta And Lorenzo
# 1  Fortezza/City Centre Modern Apt 2+1    99178  Benedetta And Lorenzo
# 2  Fortezza/City Centre Modern Apt 4+2    99178  Benedetta And Lorenzo
# 3  Fortezza/City Centre Modern Apt 4+2    99178  Benedetta And Lorenzo
# 4             N4U Guest House Florence   113883        N4U Guest House
#
#    host_since             host_location  host_total_listings_count  \
# 0  2010-03-26  Florence, Toscana, Italy                          5
# ...

# %% [markdown]
# keeping only the columns we want

# %%
listings_location = listings_location[["name", "host_total_listings_count", "price", "listing_url", "host_name", "longitude", "latitude"]]

# %% [markdown]
# creating the map

# %%
#m = folium.Map(location=[45.5236, -122.6750])
map = folium.Map(location=[listings_location.latitude.mean(),listings_location.longitude.mean()], zoom_start=12, control_scale=True) #defaults to OSM can adjust tiles but need attribution can't figure that out

# %% [markdown]
# show map

# %%
map.save("firenze_folium_map.html") 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Adding points to the map, by loopin over all listings rows in dataframe and pulling out important location info and popup information like name from other columns not long lat

# %%
for index, location_info in listings_location.iterrows():
    folium.Marker([location_info["latitude"],location_info["longitude"]], popup=[location_info["name"],location_info["price"],location_info["host_total_listings_count"]]).add_to(map)
#why was location_info not an issue? never declared it before?

# %%
map.save("firenze_folium_map.html")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# other fun things to customize

# %%
#can pass escaped html into popup 
#parse_html=True 
#popup (string or folium.Popup, default None) – Label for the Marker; either an escaped HTML string to initialize folium.Popup or a folium.Popup instance.
#this isn't html but it's prettier... 
for index, location_info in listings_location.iterrows():
    folium.Marker([location_info["latitude"],location_info["longitude"]], popup="Total Listings Count: " + str(location_info["host_total_listings_count"])).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#tooltip (str or folium.Tooltip, default None) – Display a text when hovering over the object.
for index, location_info in listings_location.iterrows():
    folium.Marker([location_info["latitude"],location_info["longitude"]], popup=[location_info["name"],location_info["price"],location_info["host_total_listings_count"]], tooltip=location_info["name"]).add_to(map)

# %%
map.save("firenze_folium_map.html")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#can customize icon
#icon (Icon plugin) – the Icon plugin to use to render the marker.
for index, location_info in listings_location.iterrows():
    folium.CircleMarker([location_info["latitude"],location_info["longitude"]], radius=10, popup=[location_info["name"],location_info["price"],location_info["host_total_listings_count"]], tooltip=location_info["name"]).add_to(map)
    folium.map.Icon(icon_color="beige").add_to(map) #that didn't work

#none of this is updating.. .not sure why

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
